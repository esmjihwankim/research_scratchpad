# %%
# https://timeseriesclassification.com/description.php?Dataset=ECG5000
from sklearn.metrics import confusion_matrix, classification_report
from glob import glob 
import time 
import copy 
import shutil

import pandas as pd

import torch
from torch import nn, optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import arff2pandas

# %matplotlib inline

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
with open('ECG5000/ECG5000_TRAIN.arff') as f:
    train = arff2pandas.load(f)

with open('ECG5000/ECG5000_TEST.arff') as f:
    test = arff2pandas.load(f)

train.head()
# Out:
# c:\Users\Jihwan\Desktop\EdgeECG\arff2pandas.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[df_str.columns] = df_str.applymap(lambda x:x.decode('utf-8'))
# c:\Users\Jihwan\Desktop\EdgeECG\arff2pandas.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[df_str.columns] = df_str.applymap(lambda x:x.decode('utf-8'))
#        att1      att2      att3      att4  ...    att138    att139    att140  target
# 0 -0.112522 -2.827204 -3.773897 -4.349751  ...  0.123431  0.925286  0.193137       1
# 1 -1.100878 -3.996840 -4.285843 -4.506579  ...  0.773820  1.119621 -1.436250       1
# 2 -0.567088 -2.593450 -3.874230 -4.584095  ...  0.321097  0.904227 -0.421797       1
# 3  0.490473 -1.914407 -3.616364 -4.318823  ...  1.086798  1.403011 -0.383564       1
# 4  0.800232 -0.874252 -2.384761 -3.973292  ...  0.971020  1.614392  1.421456       1
#
# [5 rows x 141 columns]

# %%
df = pd.concat([train, test], ignore_index=True)
df = df.sample(frac=1.0)    # shuffle
print(df.shape)
df.head()
# Out:
# (5000, 141)
#           att1      att2      att3  ...    att139    att140  target
# 3922 -0.671608 -1.975100 -0.450994  ...  0.793339  4.888192       2
# 2911  1.758757  0.489438 -1.522232  ...  1.036171  1.615752       1
# 99    0.004070 -2.371060 -3.421238  ... -0.403784 -1.901620       1
# 2312 -1.690646 -3.639005 -4.377955  ...  0.585283  0.429469       1
# 3396  0.497458 -0.201420 -0.725959  ... -0.533975 -0.137265       2
#
# [5 rows x 141 columns]
